# %% [markdown]
# ## STRONG SCALING (MPI)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Leggi il file CSV utilizzando Pandas
data = pd.read_csv("C:\Users\minut\OneDrive\Desktop\HPC_ex\HPC_Ex\HPC_ex2\csvs\mpi_strong_thin.csv")

# Estrai le colonne
x = data["Total Tasks"]
y = data["Execution Time (s)"]

# Plotta i dati
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Total Tasks')
plt.ylabel('Execution Time (s)')
plt.title('Execution Time vs Total Tasks')

# Imposta l'asse y da 2.4 a 3.1 con passo 0.05
#plt.ylim(2.4, 3.1)
#plt.yticks(np.arange(2.4, 3.1, 0.05))

# Imposta l'asse x con incrementi di dieci
#plt.xticks(np.arange(min(x), max(x)+1, 10))

plt.grid(True)
plt.show()

# %% [markdown]
# ## STRONG SCALING (OMP)

# %%
# Leggi il file CSV utilizzando Pandas
data = pd.read_csv("execution_times_omp.csv")

# Estrai le colonne
x = data["OMP_NUM_THREADS"]
y = data["Execution_Time"]

# Plotta i dati
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Number of Threads')
plt.ylabel('Execution Time (s)')
plt.title('Execution Time vs Number of Threads')

# Imposta l'asse y da 2.4 a 3.1 con passo 0.05
#plt.ylim(0.215, 0.225)
#plt.yticks(np.arange(0.215, 0.225, 0.005))

# Imposta l'asse x con incrementi di dieci
#plt.xticks(np.arange(min(x), max(x)+1, 10))

plt.grid(True)
plt.show()

# %% [markdown]
# ## WEAK SCALING (MPI)

# %%
# Leggi il file CSV utilizzando Pandas
data = pd.read_csv("weak_scaling_mpi.csv")

# Estrai le colonne
x = data["MPI_Processes"]
y = data["Execution_Time"]

# Plotta i dati
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Total Tasks')
plt.ylabel('Execution Time (s)')
plt.title('Execution Time vs Total Tasks')
plt.grid(True)
plt.show()

# %% [markdown]
# ## WEAK SCALING (OMP)

# %%
# Leggi il file CSV utilizzando Pandas
data = pd.read_csv("weak_scaling_omp.csv")

# Estrai le colonne
threads = data["OMP_NUM_THREADS"]
execution_times = data["Execution_Time"]

# Plotta i dati
plt.figure(figsize=(10, 6))
plt.plot(threads, execution_times, marker='o', linestyle='-')
plt.xlabel('OMP_NUM_THREADS')
plt.ylabel('Execution Time (s)')
plt.title('Execution Time vs OMP_NUM_THREADS')
plt.grid(True)
plt.show()
